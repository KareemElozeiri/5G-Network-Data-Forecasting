# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
UE1_dfs = []
UE2_dfs = []
UE3_dfs = []

# %%
def load_data(user_num, UE_list):
    for i in range(13):
        UE_list.append(pd.read_csv(f"../data/UE{user_num}-CQI/UE{user_num}-CQI_{i+1}.csv"))

# %%
load_data(1, UE1_dfs)
load_data(2, UE2_dfs)
load_data(3, UE3_dfs)

# %%
i=1
for df in UE1_dfs:
    df["UE1-CQI"].hist()
    i+=1
    plt.show()

# %%
i=1
for df in UE2_dfs:
    df["UE2-CQI"].hist()
    i+=1
    plt.show()

# %%
i=1
for df in UE3_dfs:
    df["UE3-CQI"].hist()
    i+=1
    plt.show()
